# %% [markdown]
# ###  CoinCap is a useful tool for real-time pricing and market activity for over 1,000 cryptocurrencies. Check the documentation at https://docs.coincap.io/

# %%
import requests
import pandas as pd 
import time

# %%
url = 'https://api.coincap.io/v2/assets'

response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
res = response.json()
res
# Out:
# {'data': [{'id': 'bitcoin',
#    'rank': '1',
#    'symbol': 'BTC',
#    'name': 'Bitcoin',
#    'supply': '19719981.0000000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '1133601989100.2048903712999165',
#    'volumeUsd24Hr': '11496631843.4957849703100592',
#    'priceUsd': '57484.9432715074568465',
#    'changePercent24Hr': '0.0033087648300975',
#    'vwap24Hr': '58109.9663121234943209',
#    'explorer': 'https://blockchain.info/'},
#   {'id': 'ethereum',
#    'rank': '2',
#    'symbol': 'ETH',
#    'name': 'Ethereum',
#    'supply': '120209171.4182295800000000',
#    'maxSupply': None,
#    'marketCapUsd': '374166999304.0414454405785504',
#    'volumeUsd24Hr': '7823587381.4884497073790845',
#    'priceUsd': '3112.6327125427590993',
#    'changePercent24Hr': '0.1506585378871900',
#    'vwap24Hr': '3131.2178350280849755',
#    'explorer': 'https://etherscan.io/'},
#   {'id': 'tether',
#    'rank': '3',
#    'symbol': 'USDT',
#    'name': 'Tether',
#    'supply': '112259808785.1427800000000000',
#    'maxSupply': None,
#    'marketCapUsd': '112339487418.6182479116843233',
#    'volumeUsd24Hr': '14884767944.1808987819017316',
#    'priceUsd': '1.0007097699019599',
#    'changePercent24Hr': '0.0454104874957701',
#    'vwap24Hr': '1.0002086623431707',
#    'explorer': 'https://www.omniexplorer.info/asset/31'},
#   {'id': 'binance-coin',
#    'rank': '4',
#    'symbol': 'BNB',
#    'name': 'BNB',
#    'supply': '166801148.0000000000000000',
#    'maxSupply': '166801148.0000000000000000',
#    'marketCapUsd': '87803280786.2309069797341820',
#    'volumeUsd24Hr': '293996967.9271148339139536',
#    'priceUsd': '526.3949429546546465',
#    'changePercent24Hr': '0.4520549411856290',
#    'vwap24Hr': '530.7011370922360641',
#    'explorer': 'https://etherscan.io/token/0xB8c77482e45F1F44dE1745F52C74426C631bDD52'},
#   {'id': 'solana',
#    'rank': '5',
#    'symbol': 'SOL',
#    'name': 'Solana',
#    'supply': '463960292.5906939500000000',
#    'maxSupply': None,
#    'marketCapUsd': '63562782558.8671001338271803',
#    'volumeUsd24Hr': '684748484.1682447994936218',
#    'priceUsd': '137.0004795107374097',
#    'changePercent24Hr': '-3.0624055379031220',
#    'vwap24Hr': '141.2464694532299801',
#    'explorer': 'https://explorer.solana.com/'},
#   {'id': 'usd-coin',
#    'rank': '6',
#    'symbol': 'USDC',
#    'name': 'USDC',
#    'supply': '33908382580.8915520000000000',
#    'maxSupply': None,
#    'marketCapUsd': '33928318463.3202697879514481',
#    'volumeUsd24Hr': '1255980666.8501628501771423',
#    'priceUsd': '1.0005879337470951',
#    'changePercent24Hr': '0.0345654361585249',
#    'vwap24Hr': '1.0001766462168476',
#    'explorer': 'https://etherscan.io/token/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'},
#   {'id': 'xrp',
#    'rank': '7',
#    'symbol': 'XRP',
#    'name': 'XRP',
#    'supply': '45404028640.0000000000000000',
#    'maxSupply': '100000000000.0000000000000000',
#    'marketCapUsd': '20326731968.4828586738211200',
#    'volumeUsd24Hr': '484324146.0183265896829280',
#    'priceUsd': '0.4476856476690580',
#    'changePercent24Hr': '2.5266954136642845',
#    'vwap24Hr': '0.4446461826142228',
#    'explorer': 'https://xrpcharts.ripple.com/#/graph/'},
#   {'id': 'dogecoin',
#    'rank': '8',
#    'symbol': 'DOGE',
#    'name': 'Dogecoin',
#    'supply': '145075296383.7052000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '15551430550.8286671897239323',
#    'volumeUsd24Hr': '157753194.9443408210636771',
#    'priceUsd': '0.1071955800779284',
#    'changePercent24Hr': '-0.7627728630148195',
#    'vwap24Hr': '0.1087525918334452',
#    'explorer': 'http://dogechain.info/chain/Dogecoin'},
#   {'id': 'cardano',
#    'rank': '9',
#    'symbol': 'ADA',
#    'name': 'Cardano',
#    'supply': '35875143821.4130000000000000',
#    'maxSupply': '45000000000.0000000000000000',
#    'marketCapUsd': '14207988562.8185603666862741',
#    'volumeUsd24Hr': '125399707.0795223904966566',
#    'priceUsd': '0.3960399053323978',
#    'changePercent24Hr': '2.6020445787230656',
#    'vwap24Hr': '0.3933203603474655',
#    'explorer': 'https://cardanoexplorer.com/'},
#   {'id': 'tron',
#    'rank': '10',
#    'symbol': 'TRX',
#    'name': 'TRON',
#    'supply': '87136221841.2426900000000000',
#    'maxSupply': None,
#    'marketCapUsd': '11751579610.5044941906339533',
#    'volumeUsd24Hr': '160754313.2583069576667592',
#    'priceUsd': '0.1348644612101178',
#    'changePercent24Hr': '2.7110024885367043',
#    'vwap24Hr': '0.1335521630207054',
#    'explorer': 'https://tronscan.org/#/'},
#   {'id': 'avalanche',
#    'rank': '11',
#    'symbol': 'AVAX',
#    'name': 'Avalanche',
#    'supply': '394403840.1728880000000000',
#    'maxSupply': '715748719.0000000000000000',
#    'marketCapUsd': '9980415420.2716679093255946',
#    'volumeUsd24Hr': '94168332.1731954994281968',
#    'priceUsd': '25.3050665427008154',
#    'changePercent24Hr': '-3.1894833004859698',
#    'vwap24Hr': '25.6922413311917557',
#    'explorer': 'https://avascan.info/'},
#   {'id': 'shiba-inu',
#    'rank': '12',
#    'symbol': 'SHIB',
#    'name': 'Shiba Inu',
#    'supply': '589270749328708.9000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '9658679581.5530839970778470',
#    'volumeUsd24Hr': '85178875.2709809918889248',
#    'priceUsd': '0.0000163909028109',
#    'changePercent24Hr': '0.1867665809241012',
#    'vwap24Hr': '0.0000165298374349',
#    'explorer': 'https://etherscan.io/token/0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce'},
#   {'id': 'wrapped-bitcoin',
#    'rank': '13',
#    'symbol': 'WBTC',
#    'name': 'Wrapped Bitcoin',
#    'supply': '153281.8946827400000000',
#    'maxSupply': None,
#    'marketCapUsd': '8824969025.4241793067594023',
#    'volumeUsd24Hr': '18166194.3759695256215160',
#    'priceUsd': '57573.4599555279194079',
#    'changePercent24Hr': '0.0030184734692022',
#    'vwap24Hr': '58266.9011292662225576',
#    'explorer': 'https://etherscan.io/token/0x2260fac5e5542a773aa44fbcfedf7c193bc2c599'},
#   {'id': 'polkadot',
#    'rank': '14',
#    'symbol': 'DOT',
#    'name': 'Polkadot',
#    'supply': '1386692924.7393100000000000',
#    'maxSupply': None,
#    'marketCapUsd': '8234866971.2304615707368401',
#    'volumeUsd24Hr': '61137978.1281988511089277',
#    'priceUsd': '5.9384935369008012',
#    'changePercent24Hr': '-2.8655006736069681',
#    'vwap24Hr': '6.0987759488282567',
#    'explorer': 'https://polkascan.io/polkadot'},
#   {'id': 'chainlink',
#    'rank': '15',
#    'symbol': 'LINK',
#    'name': 'Chainlink',
#    'supply': '608099970.4527867000000000',
#    'maxSupply': None,
#    'marketCapUsd': '7633110586.4743203647672920',
#    'volumeUsd24Hr': '159007881.9124264764942632',
#    'priceUsd': '12.5523942729199003',
#    'changePercent24Hr': '-1.8289319273659384',
#    'vwap24Hr': '12.8204281974533310',
#    'explorer': 'https://etherscan.io/token/0x514910771af9ca656af840dff83e8264ecf986ca'},
#   {'id': 'bitcoin-cash',
#    'rank': '16',
#    'symbol': 'BCH',
#    'name': 'Bitcoin Cash',
#    'supply': '19731493.7500000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '6894832111.4648153444423719',
#    'volumeUsd24Hr': '113470856.7381668617874336',
#    'priceUsd': '349.4328507929013405',
#    'changePercent24Hr': '3.7823214382227029',
#    'vwap24Hr': '347.3569581019886746',
#    'explorer': 'https://blockchair.com/bitcoin-cash/blocks'},
#   {'id': 'near-protocol',
#    'rank': '17',
#    'symbol': 'NEAR',
#    'name': 'NEAR Protocol',
#    'supply': '1096768596.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '5423430205.6443816188398440',
#    'volumeUsd24Hr': '91705898.4567382431561094',
#    'priceUsd': '4.9449174834363890',
#    'changePercent24Hr': '6.5678567838315358',
#    'vwap24Hr': '4.7623518655805293',
#    'explorer': 'https://explorer.nearprotocol.com/'},
#   {'id': 'unus-sed-leo',
#    'rank': '18',
#    'symbol': 'LEO',
#    'name': 'UNUS SED LEO',
#    'supply': '926020477.9000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '5410070604.9921787687066283',
#    'volumeUsd24Hr': '2667414.5032830448205127',
#    'priceUsd': '5.8422796623903675',
#    'changePercent24Hr': '-0.1786253089757727',
#    'vwap24Hr': '5.7388285459894835',
#    'explorer': 'https://eospark.com/account/bitfinexleo1'},
#   {'id': 'multi-collateral-dai',
#    'rank': '19',
#    'symbol': 'DAI',
#    'name': 'Multi Collateral DAI',
#    'supply': '5347888595.7464075000000000',
#    'maxSupply': None,
#    'marketCapUsd': '5346656885.8243831851856350',
#    'volumeUsd24Hr': '109769543.5835855157877592',
#    'priceUsd': '0.9997696829505753',
#    'changePercent24Hr': '-0.0295106773728419',
#    'vwap24Hr': '1.0003217789252316',
#    'explorer': 'https://etherscan.io/token/0x89d24a6b4ccb1b6faa2625fe562bdd9a23260359'},
#   {'id': 'litecoin',
#    'rank': '20',
#    'symbol': 'LTC',
#    'name': 'Litecoin',
#    'supply': '74738793.6075049000000000',
#    'maxSupply': '84000000.0000000000000000',
#    'marketCapUsd': '5114649172.9762602872214820',
#    'volumeUsd24Hr': '142687351.5816371011840478',
#    'priceUsd': '68.4336597649158805',
#    'changePercent24Hr': '2.5022069288286955',
#    'vwap24Hr': '67.8651098352322748',
#    'explorer': 'http://explorer.litecoin.net/chain/Litecoin'},
#   {'id': 'polygon',
#    'rank': '21',
#    'symbol': 'MATIC',
#    'name': 'Polygon',
#    'supply': '9894059780.2208440000000000',
#    'maxSupply': None,
#    'marketCapUsd': '4991019782.8054694588900455',
#    'volumeUsd24Hr': '69514985.5406280761431847',
#    'priceUsd': '0.5044460912580079',
#    'changePercent24Hr': '-1.7472783626177602',
#    'vwap24Hr': '0.5125757177795015',
#    'explorer': 'https://etherscan.io/token/0x7D1AfA7B718fb893dB30A3aBc0Cfc608AaCfeBB0'},
#   {'id': 'uniswap',
#    'rank': '22',
#    'symbol': 'UNI',
#    'name': 'Uniswap',
#    'supply': '600034294.7100000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '4745274221.2083685208193670',
#    'volumeUsd24Hr': '75121802.4729189218279884',
#    'priceUsd': '7.9083383450637378',
#    'changePercent24Hr': '-1.9425970530372557',
#    'vwap24Hr': '7.9966022650096245',
#    'explorer': 'https://etherscan.io/token/0x1f9840a85d5af5bf1d1762f925bdaddc4201f984'},
#   {'id': 'internet-computer',
#    'rank': '23',
#    'symbol': 'ICP',
#    'name': 'Internet Computer',
#    'supply': '466123913.4144278000000000',
#    'maxSupply': None,
#    'marketCapUsd': '3450931840.4252710518536334',
#    'volumeUsd24Hr': '21243243.8158038847786946',
#    'priceUsd': '7.4034644889739213',
#    'changePercent24Hr': '2.7750123800235405',
#    'vwap24Hr': '7.3850881427908892',
#    'explorer': 'https://www.dfinityexplorer.org/#/'},
#   {'id': 'ethereum-classic',
#    'rank': '24',
#    'symbol': 'ETC',
#    'name': 'Ethereum Classic',
#    'supply': '147878551.3315075600000000',
#    'maxSupply': '210700000.0000000000000000',
#    'marketCapUsd': '3121059143.5071032168722516',
#    'volumeUsd24Hr': '65611739.1541723012220541',
#    'priceUsd': '21.1055566571682977',
#    'changePercent24Hr': '0.4257491360874887',
#    'vwap24Hr': '21.1040014427419142',
#    'explorer': 'http://gastracker.io/'},
#   {'id': 'fetch',
#    'rank': '25',
#    'symbol': 'FET',
#    'name': 'Artificial Superintelligence Alliance',
#    'supply': '2520000000.0000000000000000',
#    'maxSupply': '2630547141.0000000000000000',
#    'marketCapUsd': '2928919149.7925627520000000',
#    'volumeUsd24Hr': '46882873.3000712053593640',
#    'priceUsd': '1.1622695038859376',
#    'changePercent24Hr': '-2.9472729856435984',
#    'vwap24Hr': '1.1963489827936485',
#    'explorer': 'https://etherscan.io/token/0x1d287cc25dad7ccaf76a26bc660c5f7c8e2a05bd'},
#   {'id': 'monero',
#    'rank': '26',
#    'symbol': 'XMR',
#    'name': 'Monero',
#    'supply': '18446744.0737095500000000',
#    'maxSupply': None,
#    'marketCapUsd': '2927560167.6200434560071770',
#    'volumeUsd24Hr': '49505549.8952603578987848',
#    'priceUsd': '158.7033546907839453',
#    'changePercent24Hr': '0.4784703402900458',
#    'vwap24Hr': '157.9271056675913300',
#    'explorer': 'http://moneroblocks.info/'},
#   {'id': 'stellar',
#    'rank': '27',
#    'symbol': 'XLM',
#    'name': 'Stellar',
#    'supply': '29227062904.5475850000000000',
#    'maxSupply': '50001806812.0000000000000000',
#    'marketCapUsd': '2605768616.2617635143233471',
#    'volumeUsd24Hr': '28135196.2008346113154049',
#    'priceUsd': '0.0891560203901405',
#    'changePercent24Hr': '2.2227387532323606',
#    'vwap24Hr': '0.0885254652976805',
#    'explorer': 'https://dashboard.stellar.org/'},
#   {'id': 'filecoin',
#    'rank': '28',
#    'symbol': 'FIL',
#    'name': 'Filecoin',
#    'supply': '569587345.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '2386604572.8529273041391885',
#    'volumeUsd24Hr': '70439044.6586437137899204',
#    'priceUsd': '4.1900589853395133',
#    'changePercent24Hr': '6.0848146644231197',
#    'vwap24Hr': '4.0558218792963571',
#    'explorer': 'https://protocol.ai'},
#   {'id': 'stacks',
#    'rank': '29',
#    'symbol': 'STX',
#    'name': 'Stacks',
#    'supply': '1473817680.5993930000000000',
#    'maxSupply': '1818000000.0000000000000000',
#    'marketCapUsd': '2367172103.9250140609781439',
#    'volumeUsd24Hr': '35205346.2630525879225717',
#    'priceUsd': '1.6061498888806240',
#    'changePercent24Hr': '6.2606136681144706',
#    'vwap24Hr': '1.6005941483865172',
#    'explorer': 'https://explorer.xinfin.network/'},
#   {'id': 'render-token',
#    'rank': '30',
#    'symbol': 'RNDR',
#    'name': 'Render Token',
#    'supply': '369614008.1087959400000000',
#    'maxSupply': '536870912.0000000000000000',
#    'marketCapUsd': '2231301904.6209733505201682',
#    'volumeUsd24Hr': '9319690.9303682240218997',
#    'priceUsd': '6.0368434520051775',
#    'changePercent24Hr': '-7.4210989468426502',
#    'vwap24Hr': '6.3761295942712525',
#    'explorer': 'https://etherscan.io/token/0x6de037ef9ad2725eb40118bb1702ebb27e4aeb24'},
#   {'id': 'maker',
#    'rank': '31',
#    'symbol': 'MKR',
#    'name': 'Maker',
#    'supply': '930158.7087166800000000',
#    'maxSupply': '1005577.0000000000000000',
#    'marketCapUsd': '2181327757.2541679840938611',
#    'volumeUsd24Hr': '35116762.2164733379093044',
#    'priceUsd': '2345.1135132236723966',
#    'changePercent24Hr': '1.5312300883116469',
#    'vwap24Hr': '2306.9996847830977642',
#    'explorer': 'https://etherscan.io/token/Maker'},
#   {'id': 'crypto-com-coin',
#    'rank': '32',
#    'symbol': 'CRO',
#    'name': 'Crypto.com Coin',
#    'supply': '25263013692.0000000000000000',
#    'maxSupply': '30263013692.0000000000000000',
#    'marketCapUsd': '2168861253.1461615101177676',
#    'volumeUsd24Hr': '3227908.2093575290278732',
#    'priceUsd': '0.0858512479781053',
#    'changePercent24Hr': '0.9271131190912642',
#    'vwap24Hr': '0.0852406338054745',
#    'explorer': 'https://etherscan.io/token/0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b'},
#   {'id': 'vechain',
#    'rank': '33',
#    'symbol': 'VET',
#    'name': 'VeChain',
#    'supply': '80985041177.0000000000000000',
#    'maxSupply': '86712634466.0000000000000000',
#    'marketCapUsd': '2167261258.1987846482786982',
#    'volumeUsd24Hr': '17508882.1912562069875520',
#    'priceUsd': '0.0267612540130966',
#    'changePercent24Hr': '3.0359971446474057',
#    'vwap24Hr': '0.0266669992427982',
#    'explorer': 'https://explore.veforge.com/'},
#   {'id': 'the-graph',
#    'rank': '34',
#    'symbol': 'GRT',
#    'name': 'The Graph',
#    'supply': '9548531509.1654740000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1767572134.8083142171665502',
#    'volumeUsd24Hr': '21046484.0756919446995629',
#    'priceUsd': '0.1851145522336761',
#    'changePercent24Hr': '-0.6547909970799479',
#    'vwap24Hr': '0.1878023942744151',
#    'explorer': 'https://etherscan.io/token/0xc944e90c64b2c07662a292be6244bdf05cda44a7'},
#   {'id': 'arweave',
#    'rank': '35',
#    'symbol': 'AR',
#    'name': 'Arweave',
#    'supply': '65652466.0000000000000000',
#    'maxSupply': '66000000.0000000000000000',
#    'marketCapUsd': '1556337364.3303116168771442',
#    'volumeUsd24Hr': '47826712.4992304726629832',
#    'priceUsd': '23.7056954468444737',
#    'changePercent24Hr': '4.6524299980230113',
#    'vwap24Hr': '23.4252238143581692',
#    'explorer': 'https://viewblock.io/arweave'},
#   {'id': 'cosmos',
#    'rank': '36',
#    'symbol': 'ATOM',
#    'name': 'Cosmos',
#    'supply': '248453201.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1499967392.7854553306193947',
#    'volumeUsd24Hr': '29182921.5667498968270869',
#    'priceUsd': '6.0372230534693547',
#    'changePercent24Hr': '0.2760651585215878',
#    'vwap24Hr': '6.0709632417445042',
#    'explorer': 'https://www.mintscan.io/'},
#   {'id': 'injective-protocol',
#    'rank': '37',
#    'symbol': 'INJ',
#    'name': 'Injective',
#    'supply': '73005554.3300000000000000',
#    'maxSupply': '100000000.0000000000000000',
#    'marketCapUsd': '1466234519.8270119120267149',
#    'volumeUsd24Hr': '23394054.2022414542551484',
#    'priceUsd': '20.0838762650761166',
#    'changePercent24Hr': '-3.0953728734137618',
#    'vwap24Hr': '20.5583737977919500',
#    'explorer': 'https://etherscan.io/token/0xe28b3b32b6c345a34ff64674606124dd5aceca30'},
#   {'id': 'lido-dao',
#    'rank': '38',
#    'symbol': 'LDO',
#    'name': 'Lido DAO',
#    'supply': '892895588.5033206000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1437583571.0539251921870485',
#    'volumeUsd24Hr': '4394962.7232145945468979',
#    'priceUsd': '1.6100242733460195',
#    'changePercent24Hr': '-2.0473463496014515',
#    'vwap24Hr': '1.6491302653691198',
#    'explorer': 'https://etherscan.io/token/0x5a98fcbea516cf06857215779fd812ca3bef1b32'},
#   {'id': 'aave',
#    'rank': '39',
#    'symbol': 'AAVE',
#    'name': 'Aave',
#    'supply': '14871201.6897805100000000',
#    'maxSupply': None,
#    'marketCapUsd': '1390396422.0369569939849933',
#    'volumeUsd24Hr': '38562507.3875001914996939',
#    'priceUsd': '93.4959024187290415',
#    'changePercent24Hr': '3.8778804842797776',
#    'vwap24Hr': '91.6759674597865082',
#    'explorer': 'https://etherscan.io/token/0x80fB784B7eD66730e8b1DBd9820aFD29931aab03'},
#   {'id': 'theta',
#    'rank': '40',
#    'symbol': 'THETA',
#    'name': 'THETA',
#    'supply': '1000000000.0000000000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '1369428998.5538151000000000',
#    'volumeUsd24Hr': '11030495.4375409857318801',
#    'priceUsd': '1.3694289985538151',
#    'changePercent24Hr': '-0.5621590507435563',
#    'vwap24Hr': '1.3813954806037956',
#    'explorer': 'https://explorer.thetatoken.org/'},
#   {'id': 'fantom',
#    'rank': '41',
#    'symbol': 'FTM',
#    'name': 'Fantom',
#    'supply': '2803634835.5265927000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1309448116.5557620872678111',
#    'volumeUsd24Hr': '39447916.7275571198871524',
#    'priceUsd': '0.4670537332333492',
#    'changePercent24Hr': '-0.4397372651872449',
#    'vwap24Hr': '0.4723144218393612',
#    'explorer': 'https://etherscan.io/token/0x4e15361fd6b4bb609fa63c81a2be19d873717870'},
#   {'id': 'thorchain',
#    'rank': '42',
#    'symbol': 'RUNE',
#    'name': 'THORChain',
#    'supply': '336630813.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1195489989.2246930822311506',
#    'volumeUsd24Hr': '30887472.1908828561232173',
#    'priceUsd': '3.5513385675264762',
#    'changePercent24Hr': '-1.7540692466342901',
#    'vwap24Hr': '3.6345243482582139',
#    'explorer': 'https://explorer.binance.org/asset/RUNE-B1A'},
#   {'id': 'algorand',
#    'rank': '43',
#    'symbol': 'ALGO',
#    'name': 'Algorand',
#    'supply': '8228347431.3279580000000000',
#    'maxSupply': '10000000000.0000000000000000',
#    'marketCapUsd': '1139036758.0548239224252228',
#    'volumeUsd24Hr': '18807209.7867846926848009',
#    'priceUsd': '0.1384283742952012',
#    'changePercent24Hr': '-0.5676921109687208',
#    'vwap24Hr': '0.1394192279470033',
#    'explorer': 'https://algoexplorer.io/'},
#   {'id': 'hedera-hashgraph',
#    'rank': '44',
#    'symbol': 'HBAR',
#    'name': 'Hedera Hashgraph',
#    'supply': '14832756028.0000000000000000',
#    'maxSupply': '50000000000.0000000000000000',
#    'marketCapUsd': '985498353.4388462027668360',
#    'volumeUsd24Hr': '12119636.4096122362319846',
#    'priceUsd': '0.0664406770783870',
#    'changePercent24Hr': '0.6093403871695056',
#    'vwap24Hr': '0.0668174143827602',
#    'explorer': 'https://hash-hash.info/'},
#   {'id': 'elrond-egld',
#    'rank': '45',
#    'symbol': 'EGLD',
#    'name': 'MultiversX',
#    'supply': '24184559.1898415400000000',
#    'maxSupply': '31415926.0000000000000000',
#    'marketCapUsd': '867036022.8292550106049358',
#    'volumeUsd24Hr': '17354025.8564870752574607',
#    'priceUsd': '35.8508094368510973',
#    'changePercent24Hr': '-3.3089750226910264',
#    'vwap24Hr': '36.3660463915790710',
#    'explorer': 'https://explorer.elrond.com/'},
#   {'id': 'kucoin-token',
#    'rank': '46',
#    'symbol': 'KCS',
#    'name': 'KuCoin Token',
#    'supply': '95540492.2885607500000000',
#    'maxSupply': '170118638.0000000000000000',
#    'marketCapUsd': '861038804.6055398534731186',
#    'volumeUsd24Hr': '432031.8329567942837880',
#    'priceUsd': '9.0122918982345846',
#    'changePercent24Hr': '0.7482148017555934',
#    'vwap24Hr': '9.0270309608154138',
#    'explorer': 'https://etherscan.io/token/0xf34960d9d60be18cc1d5afc1a6f012a723a28811'},
#   {'id': 'quant',
#    'rank': '47',
#    'symbol': 'QNT',
#    'name': 'Quant',
#    'supply': '12072738.0000000000000000',
#    'maxSupply': '14881364.0000000000000000',
#    'marketCapUsd': '835656253.8480866929110648',
#    'volumeUsd24Hr': '2353202.8678727022145302',
#    'priceUsd': '69.2184534981283196',
#    'changePercent24Hr': '-1.0359714486179869',
#    'vwap24Hr': '70.0660855336499014',
#    'explorer': 'https://etherscan.io/token/0x4a220e6096b25eadb88358cb44068a3248254675'},
#   {'id': 'flow',
#    'rank': '48',
#    'symbol': 'FLOW',
#    'name': 'Flow',
#    'supply': '1511780104.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '835519480.7801921501042632',
#    'volumeUsd24Hr': '11702622.7918649655624254',
#    'priceUsd': '0.5526726265079833',
#    'changePercent24Hr': '0.2519659057114497',
#    'vwap24Hr': '0.5559492740964847',
#    'explorer': 'https://flowscan.org/'},
#   {'id': 'akash-network',
#    'rank': '49',
#    'symbol': 'AKT',
#    'name': 'Akash Network',
#    'supply': '243869410.3485010000000000',
#    'maxSupply': '388539008.0000000000000000',
#    'marketCapUsd': '823715672.2773173829042835',
#    'volumeUsd24Hr': '4416276.5547658045369431',
#    'priceUsd': '3.3776916551370197',
#    'changePercent24Hr': '-4.0103248583563160',
#    'vwap24Hr': '3.4839194717744521',
#    'explorer': 'https://akash.bigdipper.live/'},
#   {'id': 'axie-infinity',
#    'rank': '50',
#    'symbol': 'AXS',
#    'name': 'Axie Infinity',
#    'supply': '147736585.9704852700000000',
#    'maxSupply': None,
#    'marketCapUsd': '796581523.6266883959309996',
#    'volumeUsd24Hr': '6033723.4051314460028644',
#    'priceUsd': '5.3919042354601926',
#    'changePercent24Hr': '0.8298926880830851',
#    'vwap24Hr': '5.3942544714635559',
#    'explorer': 'https://etherscan.io/token/0xf5d669627376ebd411e34b98f19c868c8aba5ada'},
#   {'id': 'eos',
#    'rank': '51',
#    'symbol': 'EOS',
#    'name': 'EOS',
#    'supply': '1501052610.6137000000000000',
#    'maxSupply': '2100000000.0000000000000000',
#    'marketCapUsd': '792214936.5880126835676410',
#    'volumeUsd24Hr': '37700151.1293397363205358',
#    'priceUsd': '0.5277729314658188',
#    'changePercent24Hr': '0.8746110994170261',
#    'vwap24Hr': '0.5285329468853072',
#    'explorer': 'https://bloks.io/'},
#   {'id': 'bitcoin-sv',
#    'rank': '52',
#    'symbol': 'BSV',
#    'name': 'Bitcoin SV',
#    'supply': '19727468.7500000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '760736322.0895614757863906',
#    'volumeUsd24Hr': '4195472.7022636526701240',
#    'priceUsd': '38.5622875255884755',
#    'changePercent24Hr': '3.0135826646850729',
#    'vwap24Hr': '38.3832406875580925',
#    'explorer': 'https://bsvexplorer.io/'},
#   {'id': 'tezos',
#    'rank': '53',
#    'symbol': 'XTZ',
#    'name': 'Tezos',
#    'supply': '988930690.6436740000000000',
#    'maxSupply': None,
#    'marketCapUsd': '750706408.1547666878835670',
#    'volumeUsd24Hr': '20849883.1847061213694860',
#    'priceUsd': '0.7591092229791633',
#    'changePercent24Hr': '1.6897242408387697',
#    'vwap24Hr': '0.7542939742971911',
#    'explorer': 'https://tzkt.io/'},
#   {'id': 'the-sandbox',
#    'rank': '54',
#    'symbol': 'SAND',
#    'name': 'The Sandbox',
#    'supply': '2281231926.2233224000000000',
#    'maxSupply': None,
#    'marketCapUsd': '693731345.7180580229626880',
#    'volumeUsd24Hr': '16260249.4083433714272155',
#    'priceUsd': '0.3041038211605955',
#    'changePercent24Hr': '1.4563849303375006',
#    'vwap24Hr': '0.3026845148352219',
#    'explorer': 'https://etherscan.io/token/0x3845badAde8e6dFF049820680d1F14bD3903a5d0'},
#   {'id': 'gala',
#    'rank': '55',
#    'symbol': 'GALA',
#    'name': 'Gala',
#    'supply': '32656491649.9509660000000000',
#    'maxSupply': None,
#    'marketCapUsd': '693465782.6256847780231638',
#    'volumeUsd24Hr': '15719788.8467600020733189',
#    'priceUsd': '0.0212351586955216',
#    'changePercent24Hr': '-7.7115211224739657',
#    'vwap24Hr': '0.0217200981295977',
#    'explorer': 'https://ethplorer.io/es/address/0x15d4c048f83bd7e37d49ea4c83a07267ec4203da#chart=candlestick'},
#   {'id': 'neo',
#    'rank': '56',
#    'symbol': 'NEO',
#    'name': 'Neo',
#    'supply': '70538831.0000000000000000',
#    'maxSupply': '100000000.0000000000000000',
#    'marketCapUsd': '691960976.2840008393408392',
#    'volumeUsd24Hr': '7077175.0655957187198594',
#    'priceUsd': '9.8096462115171832',
#    'changePercent24Hr': '0.1571335714193048',
#    'vwap24Hr': '9.9261492497790039',
#    'explorer': 'https://neotracker.io'},
#   {'id': 'gnosis-gno',
#    'rank': '57',
#    'symbol': 'GNO',
#    'name': 'Gnosis',
#    'supply': '2589588.0000000000000000',
#    'maxSupply': '3000000.0000000000000000',
#    'marketCapUsd': '682647737.3971199285949324',
#    'volumeUsd24Hr': '397801.7252813113288336',
#    'priceUsd': '263.6124887036547623',
#    'changePercent24Hr': '0.6737804173615988',
#    'vwap24Hr': '263.4826914874327890',
#    'explorer': 'https://etherscan.io/token/Gnosis'},
#   {'id': 'gatetoken',
#    'rank': '58',
#    'symbol': 'GT',
#    'name': 'GateToken',
#    'supply': '93096874.2769858800000000',
#    'maxSupply': None,
#    'marketCapUsd': '638393114.5155458964479108',
#    'volumeUsd24Hr': '1823984.2764397843605092',
#    'priceUsd': '6.8572991249541941',
#    'changePercent24Hr': '-0.5990469217925395',
#    'vwap24Hr': '6.9124925901506639',
#    'explorer': None},
#   {'id': 'nexo',
#    'rank': '59',
#    'symbol': 'NEXO',
#    'name': 'Nexo',
#    'supply': '560000011.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '621574717.2340791504113146',
#    'volumeUsd24Hr': '787240.7371263596216295',
#    'priceUsd': '1.1099548304010286',
#    'changePercent24Hr': '4.3613621753679380',
#    'vwap24Hr': '1.0835090951844653',
#    'explorer': 'https://etherscan.io/token/0xb62132e35a6c13ee1ee0f84dc5d40bad8d815206'},
#   {'id': 'decentraland',
#    'rank': '60',
#    'symbol': 'MANA',
#    'name': 'Decentraland',
#    'supply': '1908319865.3915880000000000',
#    'maxSupply': None,
#    'marketCapUsd': '612187321.4813379759385353',
#    'volumeUsd24Hr': '8849534.9856491688612569',
#    'priceUsd': '0.3207991137039895',
#    'changePercent24Hr': '2.7212524061035093',
#    'vwap24Hr': '0.3172712027198096',
#    'explorer': 'https://etherscan.io/token/decentraland'},
#   {'id': 'conflux-network',
#    'rank': '61',
#    'symbol': 'CFX',
#    'name': 'Conflux',
#    'supply': '4232510801.2500000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '601621832.3873777245162271',
#    'volumeUsd24Hr': '6886206.4692037435734774',
#    'priceUsd': '0.1421430117106137',
#    'changePercent24Hr': '1.4706401671647927',
#    'vwap24Hr': '0.1417839235579546',
#    'explorer': 'http://www.confluxscan.io/'},
#   {'id': 'ecash',
#    'rank': '62',
#    'symbol': 'XEC',
#    'name': 'eCash',
#    'supply': '19727535923091.0000000000000000',
#    'maxSupply': '21000000000000.0000000000000000',
#    'marketCapUsd': '600219739.7444724214036815',
#    'volumeUsd24Hr': '8250102.4370645167621685',
#    'priceUsd': '0.0000304254794965',
#    'changePercent24Hr': '-2.6862439326479110',
#    'vwap24Hr': '0.0000311832209980',
#    'explorer': 'https://explorer.bitcoinabc.org/'},
#   {'id': 'chiliz',
#    'rank': '63',
#    'symbol': 'CHZ',
#    'name': 'Chiliz',
#    'supply': '8919064798.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '588508837.3745756041977390',
#    'volumeUsd24Hr': '13281143.3906464782924861',
#    'priceUsd': '0.0659832449593305',
#    'changePercent24Hr': '-0.8587566924124097',
#    'vwap24Hr': '0.0668640347389371',
#    'explorer': 'https://etherscan.io/token/0x3506424f91fd33084466f402d5d97f05f8e3b4af'},
#   {'id': 'pendle',
#    'rank': '64',
#    'symbol': 'PENDLE',
#    'name': 'Pendle',
#    'supply': '154928384.5032312600000000',
#    'maxSupply': None,
#    'marketCapUsd': '568738762.4640190675476564',
#    'volumeUsd24Hr': '3598879.8213244812188655',
#    'priceUsd': '3.6709784607103883',
#    'changePercent24Hr': '2.3327993150946302',
#    'vwap24Hr': '3.7130949803343788',
#    'explorer': 'https://etherscan.io/token/0x808507121b80c02388fad14726482e061b8da827'},
#   {'id': 'dexe',
#    'rank': '65',
#    'symbol': 'DEXE',
#    'name': 'DeXe',
#    'supply': '57103225.3406123900000000',
#    'maxSupply': '98942301.0000000000000000',
#    'marketCapUsd': '562677498.2441047069775091',
#    'volumeUsd24Hr': '856848.9382020908317149',
#    'priceUsd': '9.8536903106228361',
#    'changePercent24Hr': '0.4060325415152783',
#    'vwap24Hr': '9.9107178062544794',
#    'explorer': 'https://etherscan.io/token/0xde4EE8057785A7e8e800Db58F9784845A5C2Cbd6'},
#   {'id': 'mina',
#    'rank': '66',
#    'symbol': 'MINA',
#    'name': 'Mina',
#    'supply': '1130803448.8400393000000000',
#    'maxSupply': None,
#    'marketCapUsd': '551186901.5735658050641267',
#    'volumeUsd24Hr': '4662404.4945506344486041',
#    'priceUsd': '0.4874294486269606',
#    'changePercent24Hr': '-2.1589074649203249',
#    'vwap24Hr': '0.4972853208245778',
#    'explorer': 'https://minaexplorer.com/'},
#   {'id': 'klaytn',
#    'rank': '67',
#    'symbol': 'KLAY',
#    'name': 'Klaytn',
#    'supply': '3702511344.3885970000000000',
#    'maxSupply': None,
#    'marketCapUsd': '543529459.2268925724983026',
#    'volumeUsd24Hr': '2643596.3385108089972069',
#    'priceUsd': '0.1468002144141024',
#    'changePercent24Hr': '0.3397980598971441',
#    'vwap24Hr': '0.1475974860645148',
#    'explorer': 'https://scope.klaytn.com/blocks'},
#   {'id': 'mantra-dao',
#    'rank': '68',
#    'symbol': 'OM',
#    'name': 'MANTRA DAO',
#    'supply': '500205033.1781248500000000',
#    'maxSupply': '888888888.0000000000000000',
#    'marketCapUsd': '533290770.7898791565584961',
#    'volumeUsd24Hr': '105706336.0372574924328316',
#    'priceUsd': '1.0661443516502409',
#    'changePercent24Hr': '12.1156992472128906',
#    'vwap24Hr': '1.0792076007490222',
#    'explorer': 'https://etherscan.io/token/0x3593d125a4f7849a1b059e64f4517a86dd60c95d'},
#   {'id': 'oasis-network',
#    'rank': '69',
#    'symbol': 'ROSE',
#    'name': 'Oasis',
#    'supply': '6713599876.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '526977493.9237142275889948',
#    'volumeUsd24Hr': '7128827.1191059196053025',
#    'priceUsd': '0.0784940275942823',
#    'changePercent24Hr': '-3.7436919379240588',
#    'vwap24Hr': '0.0815113559859932',
#    'explorer': 'https://www.oasisscan.com/'},
#   {'id': 'iota',
#    'rank': '70',
#    'symbol': 'IOTA',
#    'name': 'IOTA',
#    'supply': '3344331631.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '518655832.7042788447684548',
#    'volumeUsd24Hr': '3497069.7259439329972898',
#    'priceUsd': '0.1550850483536508',
#    'changePercent24Hr': '0.6107518386083900',
#    'vwap24Hr': '0.1565168624420817',
#    'explorer': 'https://thetangle.org/'},
#   {'id': '1inch',
#    'rank': '71',
#    'symbol': '1INCH',
#    'name': '1inch Network',
#    'supply': '1253536817.6576266000000000',
#    'maxSupply': None,
#    'marketCapUsd': '508598401.0292011642806222',
#    'volumeUsd24Hr': '14035817.7462459489369452',
#    'priceUsd': '0.4057307243512592',
#    'changePercent24Hr': '-1.1228987154687172',
#    'vwap24Hr': '0.4092781748896558',
#    'explorer': 'https://etherscan.io/token/0x111111111117dc0aa78b770fa6a738034120c302'},
#   {'id': 'wemix',
#    'rank': '72',
#    'symbol': 'WEMIX',
#    'name': 'WEMIX',
#    'supply': '407741421.2110001000000000',
#    'maxSupply': '590000000.0000000000000000',
#    'marketCapUsd': '507086360.7123896737380387',
#    'volumeUsd24Hr': '1212488.5516221531501377',
#    'priceUsd': '1.2436469152590216',
#    'changePercent24Hr': '-0.4162771239552996',
#    'vwap24Hr': '1.2492166102531955',
#    'explorer': 'https://scope.klaytn.com/token/0x5096db80b21ef45230c9e423c373f1fc9c0198dd?tabId=kctTransfer'},
#   {'id': 'pancakeswap',
#    'rank': '73',
#    'symbol': 'CAKE',
#    'name': 'PancakeSwap',
#    'supply': '268751835.1245609500000000',
#    'maxSupply': '450000000.0000000000000000',
#    'marketCapUsd': '504209328.6641653868464222',
#    'volumeUsd24Hr': '7114318.8687767918617084',
#    'priceUsd': '1.8761149237566126',
#    'changePercent24Hr': '0.7351922009485807',
#    'vwap24Hr': '1.8857285845929639',
#    'explorer': 'https://bscscan.com/token/0x0e09fabb73bd3ade0a17ecc321fd13a19e81ce82'},
#   {'id': 'trueusd',
#    'rank': '74',
#    'symbol': 'TUSD',
#    'name': 'TrueUSD',
#    'supply': '495201532.6100000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '494806055.4208075157941493',
#    'volumeUsd24Hr': '7799660.1711873198150621',
#    'priceUsd': '0.9992013813303281',
#    'changePercent24Hr': '0.0417457212188019',
#    'vwap24Hr': '0.9987558183958361',
#    'explorer': 'https://etherscan.io/token/0x8dd5fbce2f6a956c3022ba3663759011dd51e73e'},
#   {'id': 'helium',
#    'rank': '75',
#    'symbol': 'HNT',
#    'name': 'Helium',
#    'supply': '160875441.8242133300000000',
#    'maxSupply': None,
#    'marketCapUsd': '494252551.0049608837109459',
#    'volumeUsd24Hr': '1629388.6253452199363977',
#    'priceUsd': '3.0722684917007080',
#    'changePercent24Hr': '0.2680107312347497',
#    'vwap24Hr': '3.1120780418160285',
#    'explorer': 'https://explorer.helium.com/'},
#   {'id': 'raydium',
#    'rank': '76',
#    'symbol': 'RAY',
#    'name': 'Raydium',
#    'supply': '262950204.4623400000000000',
#    'maxSupply': None,
#    'marketCapUsd': '482421555.9532266717244946',
#    'volumeUsd24Hr': '8273585.3192404100844416',
#    'priceUsd': '1.8346498605682567',
#    'changePercent24Hr': '2.9991625605725411',
#    'vwap24Hr': '1.8654916334254731',
#    'explorer': 'https://explorer.solana.com/address/4k3Dyjzvzp8eMZWUXbBCjEvwSkkk59S5iCNLY3QrkX6R'},
#   {'id': 'livepeer',
#    'rank': '77',
#    'symbol': 'LPT',
#    'name': 'Livepeer',
#    'supply': '33265435.6250162200000000',
#    'maxSupply': None,
#    'marketCapUsd': '455791907.0411653806158380',
#    'volumeUsd24Hr': '7901910.1889836925244251',
#    'priceUsd': '13.7016665640296463',
#    'changePercent24Hr': '2.1316902898800318',
#    'vwap24Hr': '13.9424592472436470',
#    'explorer': 'https://explorer.livepeer.org/'},
#   {'id': 'nxm',
#    'rank': '78',
#    'symbol': 'NXM',
#    'name': 'NXM',
#    'supply': '6594067.8412913900000000',
#    'maxSupply': None,
#    'marketCapUsd': '454811637.1177649551173022',
#    'volumeUsd24Hr': '185093.8619821127845444',
#    'priceUsd': '68.9728477268280742',
#    'changePercent24Hr': '1.1986945436076901',
#    'vwap24Hr': '67.9871163642699906',
#    'explorer': 'https://etherscan.io/token/0xd7c49cee7e9188cca6ad8ff264c1da2e69d4cf3b'},
#   {'id': 'aioz-network',
#    'rank': '79',
#    'symbol': 'AIOZ',
#    'name': 'AIOZ Network',
#    'supply': '1106724244.5711417000000000',
#    'maxSupply': None,
#    'marketCapUsd': '452749478.9119677625407185',
#    'volumeUsd24Hr': '1854255.6226263764552569',
#    'priceUsd': '0.4090896907091877',
#    'changePercent24Hr': '-3.9334426292723356',
#    'vwap24Hr': '0.4211184378952850',
#    'explorer': 'https://etherscan.io/token/0x626e8036deb333b408be468f951bdb42433cbf18'},
#   {'id': 'nervos-network',
#    'rank': '80',
#    'symbol': 'CKB',
#    'name': 'Nervos Network',
#    'supply': '44535188285.3494800000000000',
#    'maxSupply': None,
#    'marketCapUsd': '443108994.3045437140490279',
#    'volumeUsd24Hr': '9221198.4509740738478714',
#    'priceUsd': '0.0099496378339173',
#    'changePercent24Hr': '-0.6285102940555503',
#    'vwap24Hr': '0.0101246045606544',
#    'explorer': 'https://explorer.nervos.org/'},
#   {'id': 'theta-fuel',
#    'rank': '81',
#    'symbol': 'TFUEL',
#    'name': 'Theta Fuel',
#    'supply': '6610459080.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '434214746.0656546554911880',
#    'volumeUsd24Hr': '846176.7238226676399023',
#    'priceUsd': '0.0656860198075161',
#    'changePercent24Hr': '-0.5884901062422327',
#    'vwap24Hr': '0.0660936890979277',
#    'explorer': 'https://explorer.thetatoken.org/'},
#   {'id': 'trust-wallet-token',
#    'rank': '82',
#    'symbol': 'TWT',
#    'name': 'Trust Wallet Token',
#    'supply': '416649900.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '425303101.6495642118113800',
#    'volumeUsd24Hr': '1615650.7588906112556698',
#    'priceUsd': '1.0207685196841862',
#    'changePercent24Hr': '0.2163812446541120',
#    'vwap24Hr': '1.0261335914076007',
#    'explorer': 'https://explorer.binance.org/asset/TWT-8C2'},
#   {'id': 'kava',
#    'rank': '83',
#    'symbol': 'KAVA',
#    'name': 'Kava',
#    'supply': '1082856129.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '423001271.5570827036208659',
#    'volumeUsd24Hr': '2715812.3135305881722130',
#    'priceUsd': '0.3906347853871571',
#    'changePercent24Hr': '0.3992910844199381',
#    'vwap24Hr': '0.3904555943539933',
#    'explorer': 'https://www.mintscan.io/kava'},
#   {'id': 'zcash',
#    'rank': '84',
#    'symbol': 'ZEC',
#    'name': 'Zcash',
#    'supply': '16328268.7500000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '396505458.2277024468085238',
#    'volumeUsd24Hr': '45036343.7427536542344201',
#    'priceUsd': '24.2833740856759506',
#    'changePercent24Hr': '5.0666553446467720',
#    'vwap24Hr': '23.7012579161937900',
#    'explorer': 'https://explorer.zcha.in/'},
#   {'id': 'compound',
#    'rank': '85',
#    'symbol': 'COMP',
#    'name': 'Compound',
#    'supply': '8359584.4865648100000000',
#    'maxSupply': None,
#    'marketCapUsd': '394646828.4750593503055742',
#    'volumeUsd24Hr': '11094465.6456424609315944',
#    'priceUsd': '47.2089048336457340',
#    'changePercent24Hr': '-1.6705187977283528',
#    'vwap24Hr': '47.9394221210705472',
#    'explorer': 'https://etherscan.io/token/0xc00e94cb662c3520282e6f5717214004a7f26888'},
#   {'id': 'ftx-token',
#    'rank': '86',
#    'symbol': 'FTT',
#    'name': 'FTX Token',
#    'supply': '328895103.8132070000000000',
#    'maxSupply': None,
#    'marketCapUsd': '393176494.6510577658241943',
#    'volumeUsd24Hr': '7114683.8324946629312795',
#    'priceUsd': '1.1954464815455532',
#    'changePercent24Hr': '0.2318258610217232',
#    'vwap24Hr': '1.1957267509698836',
#    'explorer': 'https://etherscan.io/token/0x50d1c9771902476076ecfc8b2a83ad6b9355a4c9'},
#   {'id': 'synthetix-network-token',
#    'rank': '87',
#    'symbol': 'SNX',
#    'name': 'Synthetix',
#    'supply': '233716733.4900000000000000',
#    'maxSupply': '212424133.0000000000000000',
#    'marketCapUsd': '384987505.4654196616491856',
#    'volumeUsd24Hr': '11164211.2311042561698262',
#    'priceUsd': '1.6472398005763334',
#    'changePercent24Hr': '0.3359843123489725',
#    'vwap24Hr': '1.6515281568560125',
#    'explorer': 'https://etherscan.io/token/0xc011a72400e58ecd99ee497cf89e3775d4bd732f'},
#   {'id': 'xinfin-network',
#    'rank': '88',
#    'symbol': 'XDC',
#    'name': 'XinFin Network',
#    'supply': '12293293518.5500000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '352814201.8271505042197193',
#    'volumeUsd24Hr': '1424953.6428827300065896',
#    'priceUsd': '0.0286997297587315',
#    'changePercent24Hr': '1.9868961704231146',
#    'vwap24Hr': '0.0286042707749177',
#    'explorer': 'https://etherscan.io/token/0x41ab1b6fcbb2fa9dced81acbdec13ea6315f2bf2'},
#   {'id': 'wootrade',
#    'rank': '89',
#    'symbol': 'WOO',
#    'name': 'WOO',
#    'supply': '1914986376.6880167000000000',
#    'maxSupply': None,
#    'marketCapUsd': '346885383.6260074227613011',
#    'volumeUsd24Hr': '11567985.8474489942883840',
#    'priceUsd': '0.1811424811417971',
#    'changePercent24Hr': '-1.5988269181751067',
#    'vwap24Hr': '0.1843253076970300',
#    'explorer': 'https://etherscan.io/token/0x4691937a7508860f876c9c0a2a617e7d9e945d4b'},
#   {'id': 'aragon',
#    'rank': '90',
#    'symbol': 'ANT',
#    'name': 'Aragon',
#    'supply': '43191429.8753035100000000',
#    'maxSupply': None,
#    'marketCapUsd': '342177888.5117625771895293',
#    'volumeUsd24Hr': '566517.9078138251324404',
#    'priceUsd': '7.9223561132301611',
#    'changePercent24Hr': '0.8354559261927615',
#    'vwap24Hr': '7.8945556290725548',
#    'explorer': 'https://etherscan.io/token/Aragon'},
#   {'id': 'iotex',
#    'rank': '91',
#    'symbol': 'IOTX',
#    'name': 'IoTeX',
#    'supply': '9441378929.0000000000000000',
#    'maxSupply': '10000000000.0000000000000000',
#    'marketCapUsd': '341566151.3002613313996428',
#    'volumeUsd24Hr': '2825857.5067810028711663',
#    'priceUsd': '0.0361775704448332',
#    'changePercent24Hr': '-3.0392720395518936',
#    'vwap24Hr': '0.0371834848553787',
#    'explorer': 'https://etherscan.io/token/0x6fb3e0a217407efff7ca062d46c26e5d60a14d69'},
#   {'id': 'curve-dao-token',
#    'rank': '92',
#    'symbol': 'CRV',
#    'name': 'Curve DAO Token',
#    'supply': '1192334337.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '322967661.0244242830235333',
#    'volumeUsd24Hr': '9507012.7294281844155087',
#    'priceUsd': '0.2708700496179909',
#    'changePercent24Hr': '-7.0786076512008649',
#    'vwap24Hr': '0.2864681983433602',
#    'explorer': 'https://etherscan.io/token/0xD533a949740bb3306d119CC777fa900bA034cd52'},
#   {'id': 'kusama',
#    'rank': '93',
#    'symbol': 'KSM',
#    'name': 'Kusama',
#    'supply': '15194161.9749454900000000',
#    'maxSupply': None,
#    'marketCapUsd': '318951269.7452381121632418',
#    'volumeUsd24Hr': '2065984.5797428350586284',
#    'priceUsd': '20.9916986715802317',
#    'changePercent24Hr': '-0.1318695569631293',
#    'vwap24Hr': '21.1397388132738554',
#    'explorer': 'https://kusama.subscan.io/'},
#   {'id': 'golem-network-tokens',
#    'rank': '94',
#    'symbol': 'GLM',
#    'name': 'Golem',
#    'supply': '1000000000.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '310873390.1997749000000000',
#    'volumeUsd24Hr': '178907.2052327254315892',
#    'priceUsd': '0.3108733901997749',
#    'changePercent24Hr': '-1.6113526483485305',
#    'vwap24Hr': '0.3157739735812364',
#    'explorer': 'https://etherscan.io/token/Golem'},
#   {'id': 'zilliqa',
#    'rank': '95',
#    'symbol': 'ZIL',
#    'name': 'Zilliqa',
#    'supply': '18684832691.2061040000000000',
#    'maxSupply': '21000000000.0000000000000000',
#    'marketCapUsd': '291623370.8682025672269363',
#    'volumeUsd24Hr': '5707084.4057714838132224',
#    'priceUsd': '0.0156074916852455',
#    'changePercent24Hr': '-1.0338160926042082',
#    'vwap24Hr': '0.0157216231562899',
#    'explorer': 'https://etherscan.io/token/0x05f4a42e251f2d52b8ed15e9fedaacfcef1fad27'},
#   {'id': 'dash',
#    'rank': '96',
#    'symbol': 'DASH',
#    'name': 'Dash',
#    'supply': '11874253.8800896800000000',
#    'maxSupply': '18900000.0000000000000000',
#    'marketCapUsd': '285834196.8351878127286849',
#    'volumeUsd24Hr': '18746575.4980718931365741',
#    'priceUsd': '24.0717606109520927',
#    'changePercent24Hr': '1.4160131129275054',
#    'vwap24Hr': '23.8597048533065374',
#    'explorer': 'https://explorer.dash.org'},
#   {'id': 'illuvium',
#    'rank': '97',
#    'symbol': 'ILV',
#    'name': 'Illuvium',
#    'supply': '4471878.2080871400000000',
#    'maxSupply': None,
#    'marketCapUsd': '283537457.4989125284224354',
#    'volumeUsd24Hr': '5241078.5886315973955190',
#    'priceUsd': '63.4045571693233948',
#    'changePercent24Hr': '6.1542506032218005',
#    'vwap24Hr': '62.1758280473796022',
#    'explorer': 'https://etherscan.io/token/0x767fe9edc9e0df98e07454847909b5e959d7ca0e'},
#   {'id': 'celo',
#    'rank': '98',
#    'symbol': 'CELO',
#    'name': 'Celo',
#    'supply': '542396781.0000000000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '283244494.2139212639241041',
#    'volumeUsd24Hr': '2281504.1065131458402053',
#    'priceUsd': '0.5222090250825461',
#    'changePercent24Hr': '-0.6281126780158208',
#    'vwap24Hr': '0.5270111719497363',
#    'explorer': 'https://explorer.celo.org/blocks'},
#   {'id': 'just',
#    'rank': '99',
#    'symbol': 'JST',
#    'name': 'JUST',
#    'supply': '9900000000.0000000000000000',
#    'maxSupply': '9900000000.0000000000000000',
#    'marketCapUsd': '282310485.5504409300000000',
#    'volumeUsd24Hr': '5000179.8843278077787344',
#    'priceUsd': '0.0285162106616607',
#    'changePercent24Hr': '0.3140734842954245',
#    'vwap24Hr': '0.0285700539013074',
#    'explorer': 'https://tronscan.org/#/token20/TCFLL5dx5ZJdKnWuesXxi1VPwjLVmWZZy9'},
#   {'id': 'aelf',
#    'rank': '100',
#    'symbol': 'ELF',
#    'name': 'aelf',
#    'supply': '731609229.9091900000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '277545153.8726925432858934',
#    'volumeUsd24Hr': '8513686.5517033388886312',
#    'priceUsd': '0.3793625647767490',
#    'changePercent24Hr': '-4.1803969501271892',
#    'vwap24Hr': '0.3862829959711248',
#    'explorer': 'https://etherscan.io/token/0xbf2179859fc6D5BEE9Bf9158632Dc51678a4100e'}],
#  'timestamp': 1720728375484}

# %%
pd.DataFrame(res['data'])
# Out:
#               id rank symbol      name                         supply  \
# 0        bitcoin    1    BTC   Bitcoin      19719981.0000000000000000
# 1       ethereum    2    ETH  Ethereum     120209171.4182295800000000
# 2         tether    3   USDT    Tether  112259808785.1427800000000000
# 3   binance-coin    4    BNB       BNB     166801148.0000000000000000
# 4         solana    5    SOL    Solana     463960292.5906939500000000
# ..           ...  ...    ...       ...                            ...
# 95          dash   96   DASH      Dash      11874253.8800896800000000
# 96      illuvium   97    ILV  Illuvium       4471878.2080871400000000
# 97          celo   98   CELO      Celo     542396781.0000000000000000
# 98          just   99    JST      JUST    9900000000.0000000000000000
# 99          aelf  100    ELF      aelf     731609229.9091900000000000
#
#                       maxSupply                    marketCapUsd  \
# 0     21000000.0000000000000000  1133601989100.2048903712999165
# 1                          None   374166999304.0414454405785504
# 2                          None   112339487418.6182479116843233
# 3    166801148.0000000000000000    87803280786.2309069797341820
# 4                          None    63562782558.8671001338271803
# ..                          ...                             ...
# 95    18900000.0000000000000000      285834196.8351878127286849
# 96                         None      283537457.4989125284224354
# 97  1000000000.0000000000000000      283244494.2139212639241041
# 98  9900000000.0000000000000000      282310485.5504409300000000
# 99  1000000000.0000000000000000      277545153.8726925432858934
#
#                    volumeUsd24Hr                priceUsd    changePercent24Hr  \
# 0   11496631843.4957849703100592  57484.9432715074568465   0.0033087648300975
# 1    7823587381.4884497073790845   3112.6327125427590993   0.1506585378871900
# 2   14884767944.1808987819017316      1.0007097699019599   0.0454104874957701
# 3     293996967.9271148339139536    526.3949429546546465   0.4520549411856290
# 4     684748484.1682447994936218    137.0004795107374097  -3.0624055379031220
# ..                           ...                     ...                  ...
# 95     18746575.4980718931365741     24.0717606109520927   1.4160131129275054
# 96      5241078.5886315973955190     63.4045571693233948   6.1542506032218005
# 97      2281504.1065131458402053      0.5222090250825461  -0.6281126780158208
# 98      5000179.8843278077787344      0.0285162106616607   0.3140734842954245
# 99      8513686.5517033388886312      0.3793625647767490  -4.1803969501271892
#
#                   vwap24Hr                                           explorer
# 0   58109.9663121234943209                           https://blockchain.info/
# 1    3131.2178350280849755                              https://etherscan.io/
# 2       1.0002086623431707             https://www.omniexplorer.info/asset/31
# 3     530.7011370922360641  https://etherscan.io/token/0xB8c77482e45F1F44d...
# 4     141.2464694532299801                       https://explorer.solana.com/
# ..                     ...                                                ...
# 95     23.8597048533065374                          https://explorer.dash.org
# 96     62.1758280473796022  https://etherscan.io/token/0x767fe9edc9e0df98e...
# 97      0.5270111719497363                   https://explorer.celo.org/blocks
# 98      0.0285700539013074  https://tronscan.org/#/token20/TCFLL5dx5ZJdKnW...
# 99      0.3862829959711248  https://etherscan.io/token/0xbf2179859fc6D5BEE...
#
# [100 rows x 12 columns]
